# %% [markdown]
# # StyleGAN Experimentation Notebook
#
# This notebook provides an interactive environment for experimenting with StyleGAN models.
# You can train models, generate samples, and evaluate performance.

# %%
# Import necessary libraries
import torch
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

from src.models.generator import StyleGANGenerator
from src.models.discriminator import StyleGANDiscriminator
from src.data.dataloader import create_data_loaders
from src.training.trainer import train_stylegan, save_samples
from src.evaluation.metrics import evaluate_generator
from src.utils.device import set_seed, get_device
